# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import time

# %%
#pagrindinis link'as, naudojant scrapinimui einant per pasiūlymų puslapius
burl = "https://filmux.org/"

#BeautifulSoup standartinis puslapio duomenų paruošimas
m = requests.get(burl)
d = m.content
soup = BeautifulSoup(d, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="lt">
# <head>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-111496837-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-111496837-1');
# </script>
# <meta charset="utf-8"/>
# <title>Filmux - Naujausi nemokami filmai ir serialai online</title>
# <meta content="Kino teatras, kuriame galėsite žiūrėti filmus, serialus, animaciją nemokamai ir be registracijos." name="description"/>
# <meta content="naujas, filmas, serialas, animacijos, geriausi, lietuviškai" name="keywords"/>
# <link href="https://filmux.org/index.php?do=opensearch" rel="search" title="Filmux - Naujausi nemokami filmai ir serialai online" type="application/opensearchdescription+xml"/>
# <link href="https://filmux.org/" rel="canonical"/>
# ...

# %%
a = soup.find_all("div", {"class":"short-title"})
linkai = []
for h1 in a:
    href = h1.find("a")["href"]
    linkai.append(href)
linkai
# Out:
# ['https://filmux.org/9487-leo-da-vincis-misija-mona-liza.html',
#  'https://filmux.org/9345-the-man-who-was-thursday.html',
#  'https://filmux.org/9491-death-note-l-change-the-world.html',
#  'https://filmux.org/9003-zankyou-no-terror-season-1-2014.html',
#  'https://filmux.org/7917-skambutis-3-rings-2017.html',
#  'https://filmux.org/9490-amzinai-isimylejusi-jauna-mama-1-sezonas.html',
#  'https://filmux.org/9493-bite-maja-medaus-zaidynes.html',
#  'https://filmux.org/9482-magaiveris-2-sezonas.html',
#  'https://filmux.org/9485-ftb-1-sezonas.html',
#  'https://filmux.org/8646-strele-6-sezonas.html',
#  'https://filmux.org/8953-as-zombe-4-sezonas.html',
#  'https://filmux.org/8764-vikingai-5-sezonas.html',
#  'https://filmux.org/9394-as-esu-kerstas.html',
#  'https://filmux.org/9480-fantastiniai-gyvunai-grindelvaldo-piktadarystes.html',
#  'https://filmux.org/9486-pokerio-princese.html']

# %%
video = []
for linkas in linkai[0:1]:
    print(linkas)
    linkaireq = requests.get(linkas)
    linkaicont = linkaireq.content
    linkaisoup = BeautifulSoup(linkaicont, "html.parser")
    videodiv = linkaisoup.find_all("div", {"class":"video-responsive"})
    print(videodiv)
# Out:
# https://filmux.org/9487-leo-da-vincis-misija-mona-liza.html
# [<div class="video-responsive" id="videoblock">
# <iframe allowfullscreen="true" frameborder="0" height="400" mozallowfullscreen="true" scrolling="no" src="https://srv1.filmux.org/php/filmux.php?name=film/Leo.Da.Vinci.Mission.Mona.Lisa.2018.BDRip.mp4" webkitallowfullscreen="true" width="645"></iframe>
# </div>]

# %%
ab = soup.find_all("div", {"id":"player"}) # Kaina
# linkai = []
for h1 in ab:
    print(h1)
#     href = h1.find("a")["href"]
#     linkai.append(href)
# linkai

# %%
from selenium import webdriver
from selenium.webdriver.support import ui


chromedriver = "C:\\Users\\Administrator\\Desktop\\BigData\\chromedriver.exe"
browser = webdriver.Chrome(executable_path=chromedriver)
browser.get("https://filmux.org/9487-leo-da-vincis-misija-mona-liza.html")
vidoe = driver.find_elements_by_xpath("""<video src="https://srv1.filmux.org/video/aa1bc5be1952dc565984e0a807c07969/film/Leo.Da.Vinci.Mission.Mona.Lisa.2018.BDRip.mp4" x-webkit-airplay="allow" preload="none" style="width: 100%; height: 100%; object-fit: contain; transition: filter 0.1s linear 0s; min-height: auto; max-height: none; min-width: auto; max-width: none;"></video>""")[0]
# iframe = browser.find_element_by_tag_name("iframe")
# for i in iframe:
#     print(iframe)
# browser.switch_to.frame(iframe)
# print(browser.switch_to.default_content())
# print(browser.find_element_by_tag_name('a'))
# browser.find_element_by_id("div")
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-16-c5e728775d3b> in <module>
#       6 browser = webdriver.Chrome(executable_path=chromedriver)
#       7 browser.get("https://filmux.org/9487-leo-da-vincis-misija-mona-liza.html")
# ----> 8 vidoe = driver.find_elements_by_xpath("""<video src="https://srv1.filmux.org/video/aa1bc5be1952dc565984e0a807c07969/film/Leo.Da.Vinci.Mission.Mona.Lisa.2018.BDRip.mp4" x-webkit-airplay="allow" preload="none" style="width: 100%; height: 100%; object-fit: contain; transition: filter 0.1s linear 0s; min-height: auto; max-height: none; min-width: auto; max-width: none;"></video>""")[0]
#       9 # iframe = browser.find_element_by_tag_name("iframe")
#      10 # for i in iframe:
#
# ~\AppData\Local\conda\conda\envs\pkursas\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_elements_by_xpath(self, xpath)
# ...
